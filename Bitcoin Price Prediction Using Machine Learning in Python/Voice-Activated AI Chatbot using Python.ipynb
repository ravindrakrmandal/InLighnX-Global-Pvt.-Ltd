# %% [markdown]
# #### This project implements a voice-controlled AI chatbot that can:
#
# * Listen to voice commands
#
# * Respond using speech
#
# * Search Wikipedia
#
# * Open websites
#
# * Tell time/date
#
# * Perform system commands
#
# * Handle errors gracefully
#
# * Support simple custom commands

# %% [markdown]
# ### 1. Setup

# %%
pip install speechrecognition pyttsx3 wikipedia-api pyaudio
# Out:
# Collecting speechrecognition
#   Downloading speechrecognition-3.14.5-py3-none-any.whl.metadata (30 kB)
# Collecting pyttsx3
#   Downloading pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Collecting wikipedia-api
#   Downloading wikipedia_api-0.9.0.tar.gz (20 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pyaudio
#   Downloading PyAudio-0.2.14-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Requirement already satisfied: typing-extensions in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from speechrecognition) (4.14.1)
# Collecting standard-aifc (from speechrecognition)
#   Downloading standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting audioop-lts (from speechrecognition)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting comtypes (from pyttsx3)
#   Downloading comtypes-1.4.15-py3-none-any.whl.metadata (7.8 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Requirement already satisfied: pywin32 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pyttsx3) (308)
# Requirement already satisfied: requests in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from wikipedia-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->wikipedia-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->wikipedia-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->wikipedia-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->wikipedia-api) (2024.12.14)
# Collecting standard-chunk (from standard-aifc->speechrecognition)
#   Downloading standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Downloading speechrecognition-3.14.5-py3-none-any.whl (32.9 MB)
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/32.9 MB 91.4 kB/s eta 0:05:54
#     --------------------------------------- 0.5/32.9 MB 91.4 kB/s eta 0:05:54
#     --------------------------------------- 0.5/32.9 MB 91.4 kB/s eta 0:05:54
#     --------------------------------------- 0.5/32.9 MB 91.4 kB/s eta 0:05:54
#     --------------------------------------- 0.5/32.9 MB 91.4 kB/s eta 0:05:54
#     --------------------------------------- 0.5/32.9 MB 91.4 kB/s eta 0:05:54
#     --------------------------------------- 0.8/32.9 MB 127.8 kB/s eta 0:04:11
#     --------------------------------------- 0.8/32.9 MB 127.8 kB/s eta 0:04:11
#     --------------------------------------- 0.8/32.9 MB 127.8 kB/s eta 0:04:11
#    - -------------------------------------- 1.0/32.9 MB 166.7 kB/s eta 0:03:11
#    - -------------------------------------- 1.0/32.9 MB 166.7 kB/s eta 0:03:11
#    - -------------------------------------- 1.0/32.9 MB 166.7 kB/s eta 0:03:11
#    - -------------------------------------- 1.3/32.9 MB 200.6 kB/s eta 0:02:38
#    - -------------------------------------- 1.3/32.9 MB 200.6 kB/s eta 0:02:38
#    - -------------------------------------- 1.6/32.9 MB 232.4 kB/s eta 0:02:15
#    -- ------------------------------------- 1.8/32.9 MB 268.3 kB/s eta 0:01:56
#    -- ------------------------------------- 2.4/32.9 MB 338.9 kB/s eta 0:01:30
#   Stored in directory: c:\users\ravindra mandal\appdata\local\pip\cache\wheels\5b\3c\3b\1744ee821e45812b9f85c0aa752388b613ac8c3d30e532c3aa
# Successfully built wikipedia-api
# Installing collected packages: standard-chunk, pyaudio, pypiwin32, comtypes, audioop-lts, wikipedia-api, standard-aifc, pyttsx3, speechrecognition
#
#    ------------- -------------------------- 3/9 [comtypes]
#    ------------- -------------------------- 3/9 [comtypes]
#    ------------- -------------------------- 3/9 [comtypes]
#    ------------- -------------------------- 3/9 [comtypes]
#    ------------- -------------------------- 3/9 [comtypes]
#    ------------- -------------------------- 3/9 [comtypes]
#    ------------- -------------------------- 3/9 [comtypes]
#    ------------------------------- -------- 7/9 [pyttsx3]
#    ----------------------------------- ---- 8/9 [speechrecognition]
#    ----------------------------------- ---- 8/9 [speechrecognition]
#    ----------------------------------- ---- 8/9 [speechrecognition]
#    ----------------------------------- ---- 8/9 [speechrecognition]
#    ----------------------------------- ---- 8/9 [speechrecognition]
#    ---------------------------------------- 9/9 [speechrecognition]
#
# Successfully installed audioop-lts-0.2.2 comtypes-1.4.15 pyaudio-0.2.14 pypiwin32-223 pyttsx3-2.99 speechrecognition-3.14.5 standard-aifc-3.13.0 standard-chunk-3.13.0 wikipedia-api-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (8.31.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: stack_data in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: pywin32>=300 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (308)
# Requirement already satisfied: six>=1.5 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)

# %%
# !python -m ipykernel install --user --name chatbot_env --display-name "Python (chatbot_env)"
# Out:
# Installed kernelspec chatbot_env in C:\Users\RAVINDRA MANDAL\AppData\Roaming\jupyter\kernels\chatbot_env

# %%
pip install speechrecognition
# Out:
# Requirement already satisfied: speechrecognition in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.14.5)
# Requirement already satisfied: typing-extensions in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from speechrecognition) (4.14.1)
# Requirement already satisfied: standard-aifc in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from speechrecognition) (3.13.0)
# Requirement already satisfied: audioop-lts in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from speechrecognition) (0.2.2)
# Requirement already satisfied: standard-chunk in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from standard-aifc->speechrecognition) (3.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.99)
# Requirement already satisfied: comtypes in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pyttsx3) (1.4.15)
# Requirement already satisfied: pypiwin32 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pyttsx3) (308)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wikipedia-api
# Out:
# Requirement already satisfied: wikipedia-api in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.9.0)
# Requirement already satisfied: requests in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from wikipedia-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->wikipedia-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->wikipedia-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->wikipedia-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->wikipedia-api) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio
# Out:
# Requirement already satisfied: pyaudio in C:\Users\RAVINDRA MANDAL\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.2.14)Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2. Import Required Modules

# %%
import speech_recognition as sr
import pyttsx3
import wikipediaapi
import webbrowser
import datetime
import time
import os
import ctypes
import subprocess

# %% [markdown]
# ### 3. Initialize Text-to-Speech Engine

# %%
engine = pyttsx3.init('sapi5')   # Windows
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)

# %%
#speak function
def speak(text):
    engine.say(text)
    engine.runAndWait()

# %% [markdown]
# ### 4. Greet the User (wishMe)

# %%
def wishMe():
    hour = datetime.datetime.now().hour

    if 0 <= hour < 12:
        speak("Good Morning!")
    elif 12 <= hour < 18:
        speak("Good Afternoon!")
    else:
        speak("Good Evening!")

    speak("I am your AI assistant. How can I help you?")

# %% [markdown]
# ### 5. Take Voice Command (Speech Recognition)

# %%
def takeCommand():
    r = sr.Recognizer()
    r.pause_threshold = 0.8

    with sr.Microphone() as source:
        print("Listening...")
        r.adjust_for_ambient_noise(source, duration=0.5)
        audio = r.listen(source)

    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(f"User said: {query}")
        return query.lower()

    except sr.UnknownValueError:
        speak("Sorry, I did not understand that.")
        return "none"

    except sr.RequestError:
        speak("Speech service is unavailable.")
        return "none"

# %% [markdown]
# ### 6. Wikipedia Search Function

# %%
import wikipediaapi

wiki = wikipediaapi.Wikipedia(
    language='en',
    user_agent='VoiceChatbot/1.0 (contact: your_email@example.com)',
    extract_format=wikipediaapi.ExtractFormat.WIKI
)

# %%
def search_wikipedia(query):
    page = wiki.page(query)

    if page.exists():
        summary = page.summary[:500]
        speak("According to Wikipedia")
        speak(summary)
    else:
        speak("Sorry, I could not find that on Wikipedia.")

# %%
print(wiki.page("Artificial intelligence").summary[:300])
# Out:
# Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in computer science that develops and studies methods and so

# %% [markdown]
# ### 7. System Commands

# %%
def shutdown_system():
    speak("Shutting down the system")
    os.system("shutdown /s /t 5")

def restart_system():
    speak("Restarting the system")
    os.system("shutdown /r /t 5")

def lock_system():
    speak("Locking the system")
    ctypes.windll.user32.LockWorkStation()

# %% [markdown]
# ### 8. Custom Command – Write a Note

# %%
def write_note():
    speak("What should I write?")
    note = takeCommand()

    with open("notes.txt", "a") as file:
        file.write(f"{datetime.datetime.now()} : {note}\n")

    speak("Note saved successfully.")

# %% [markdown]
# ### 9. Main Logic (Command Handler)

# %%
if __name__ == "__main__":
    wishMe()

    while True:
        query = takeCommand()

        if query == "none":
            continue

        # Open Websites
        elif "open google" in query:
            speak("Opening Google")
            webbrowser.open("https://www.google.com")

        elif "open youtube" in query:
            speak("Opening YouTube")
            webbrowser.open("https://www.youtube.com")

        # Wikipedia
        elif "wikipedia" in query:
            speak("What should I search on Wikipedia?")
            search_query = takeCommand()
            search_wikipedia(search_query)

        # Time & Date
        elif "time" in query:
            time_now = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"The time is {time_now}")

        elif "date" in query:
            date_today = datetime.date.today()
            speak(f"Today's date is {date_today}")

        # System Commands
        elif "shutdown" in query:
            shutdown_system()

        elif "restart" in query:
            restart_system()

        elif "lock system" in query:
            lock_system()

        # Custom Commands
        elif "write a note" in query:
            write_note()

        # Small Talk
        elif "how are you" in query:
            speak("I am fine. Thank you for asking.")

        elif "who are you" in query:
            speak("I am a voice activated AI chatbot created using Python.")

        # Exit
        elif "exit" in query or "quit" in query:
            speak("Goodbye. Have a nice day!")
            break

        else:
            speak("Sorry, I cannot handle that command yet.")
# Out:
# Listening...
